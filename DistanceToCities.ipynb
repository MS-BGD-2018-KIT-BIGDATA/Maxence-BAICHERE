# %%
import requests
import pandas as pd
import urllib
import urllib.request


API_KEY = ' AIzaSyBgmKfgZ6s5k_0bNK6PrWILyd-QokFbZ48 '

def getSoupFromURL(url):
    #Query the website and return the html to the variable 'page'
    page = urllib.request.urlopen(url)

    #Parse the html in the 'page' variable, and store it in Beautiful Soup format
    soup = BeautifulSoup(page)
    return soup

def getTop100Cities(soup):
    List = []
    paragraphs = soup.find('table', class_='wikitable sortable').find_all('tr')
    for par in paragraphs:
        cell = par.find('a')
        if cell != None:
            List.append(cell.text)
    ListCity = List[1 : 11]
    return ListCity

def getListOriginDest(liste):
    return "|".join(liste)

def googleMapRequest(oriDest):
    link = 'https://maps.googleapis.com/maps/api/distancematrix/json?units=metrics&origins='+oriDest+'&destinations='+oriDest+'&key='+API_KEY
    distances = requests.get(link).json()
    return distances

def getMatrixOfDistances(distance):
    rows = distance['rows']
    dist = {}
    for i, origin in enumerate(ListCity):
        dist[origin] = {}
        for j, dest in enumerate(ListCity):
            dist[origin][dest] = rows[i]['elements'][j]['distance']['value']
    return dist

def convertMatrixToDF(matrix):
    return pd.DataFrame(matrix)

def saveAsCSVFile(df):
    df.to_csv('cities.csv', sep='\t')
    
def getDFfromURL(url):
    soup = getSoupFromURL(url)
    topCities = getTop100Cities(soup)
    origiDest = getListOriginDest(topCities)
    distances = googleMapRequest(origiDest)
    matrix = getMatrixOfDistances(distances)
    df = convertMatrixToDF(matrix)
    saveAsCSVFile(df)
    return df

getDFfromURL("https://fr.wikipedia.org/wiki/Liste_des_communes_de_France_les_plus_peupl%C3%A9es")
# Out:
# /home/maxence/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/maxence/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#              Bordeaux    Lille    Lyon  Marseille  Montpellier   Nantes  \
# Bordeaux            0   814642  557097     645467       484543   346917
# Lille          808729        0  690955     999908       989159   602779
# Lyon           555450   690597       0     313764       303015   684551
# ...
